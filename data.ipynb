# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
order = pd.read_csv("data.csv")
order.head(50)
# Out:
#     student_id     location  age  sql_marks  excel_marks  python_marks  \
# 0            4       Sydney   24         95           99            87
# 1            5        Tokyo   24         99           95            89
# 2            6       Berlin   22         72           70            99
# 3            7       London   23         97           90            74
# 4            8        Tokyo   22         91           71            79
# 5            9      Toronto   20         93           88            75
# 6           10        Tokyo   18         77           87           100
# 7           11      Toronto   21         78           90            88
# 8           12    Melbourne   24         80           95            87
# 9           13       London   19         97           80            96
# 10          14      Toronto   20         81           74            88
# 11          15        Paris   24         94           93            87
# ...

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='excel_marks', y='python_marks', data=order)
# Out:
# <Axes: xlabel='excel_marks', ylabel='python_marks'>

# %%
df = pd.DataFrame(order)

df['total_marks'] = df[['sql_marks','excel_marks','python_marks','power_bi_marks','english_marks']].sum(axis=1)


location_scores = df.groupby('location')['total_marks'].mean().reset_index().sort_values(by='total_marks', ascending=False)

print("Average Total Marks by Location:")
print(location_scores)

plt.figure(figsize=(7,7))
plt.pie(location_scores['total_marks'], labels=location_scores['location'], autopct='%1.1f%%', startangle=140)
plt.title('Average Total Marks by Location')
plt.show()
# Out:
# Average Total Marks by Location:
#       location  total_marks
# 1       London   427.804348
# 7        Tokyo   427.466667
# 4     New York   427.122807
# 6       Sydney   425.792453
# 3    Melbourne   425.396552
# 8      Toronto   423.553571
# 2  Los Angeles   423.116667
# 5        Paris   422.945455
# 0       Berlin   420.134615

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='location', data=order)
# Out:
# <Axes: xlabel='location', ylabel='count'>

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='location', y='english_marks', data=order,
            color='red')
# Out:
# <Axes: xlabel='location', ylabel='english_marks'>
